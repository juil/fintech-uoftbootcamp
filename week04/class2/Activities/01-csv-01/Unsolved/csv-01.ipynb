# %% [markdown]
# # Reading a CSV as a Pandas DataFrame

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas and pathlib
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
fileName = 'people.csv'
csvpath = Path('../Resources/' +  fileName)
csvpath
# Out:
# PosixPath('../Resources/people.csv')

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame

# %%
# Use the file path to read the CSV into a DataFrame
peopleDF = pd.read_csv(csvpath, index_col='id')

# %% [markdown]
# ### 4. Display a Few Rows of the DataFrame

# %%
# Use the `head` function to display a few rows of the top of the DataFrame
peopleDF.head()
# Out:
#     first_name    last_name                            email  gender  \
# id
# 1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 4.0     Cullie          NaN               cputten3@nymag.com    Male
# 5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                               uni_grad           job_title  \
# id
# 1.0                                  Aurora University  Nurse Practicioner
# 2.0                      Osaka University of Economics     Project Manager
# 3.0                                  Ludong University  Environmental Tech
# 4.0  Université des Sciences et de la Technologie d...     Legal Assistant
# 5.0                             Boise State University     Project Manager
#
#       Income
# id
# 1.0  58135.0
# 2.0  96053.0
# 3.0  59196.0
# 4.0  88493.0
# 5.0  89073.0

# %% [markdown]
# ### 5. Generate Summary Statistics on the DataFrame

# %%
# Use the `include` parameter set to 'all' to include all columns (and datatypes)
peopleDF.describe(include='all')
# Out:
#        first_name last_name                 email gender  \
# count         993       990                   992    998
# unique        914       974                   991      2
# top        Israel      Yang  ayang@codedrills.com   Male
# freq            3         2                     2    508
# mean          NaN       NaN                   NaN    NaN
# std           NaN       NaN                   NaN    NaN
# min           NaN       NaN                   NaN    NaN
# 25%           NaN       NaN                   NaN    NaN
# 50%           NaN       NaN                   NaN    NaN
# 75%           NaN       NaN                   NaN    NaN
# max           NaN       NaN                   NaN    NaN
#
#                                                  uni_grad  \
# count                                                 991
# unique                                                939
# top     Université des Sciences et de la Technologie d...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                     job_title         Income
# count                     998     998.000000
# unique                    183            NaN
# top     Chief Design Engineer            NaN
# freq                       16            NaN
# mean                      NaN   84691.693387
# std                       NaN   20185.664319
# min                       NaN   50013.000000
# 25%                       NaN   67353.000000
# 50%                       NaN   84296.000000
# 75%                       NaN  102374.750000
# max                       NaN  119987.000000
