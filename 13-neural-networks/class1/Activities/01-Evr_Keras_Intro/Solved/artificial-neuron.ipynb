# %% [markdown]
# # Activating Your First Artificial Neuron

# %%
# Initial imports
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs, make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %matplotlib inline
# Out:
# 2023-02-16 20:05:09.361912: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Using a Single Neuron for Binary Classification
#
# ### Creating Dummy Data

# %%
# Generate 1000 demo data samples with 2 features and two centers
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# %%
# Transforming y to a vertical vector
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   5.478098   7.203714       1
# 1  -8.428483   4.121889       0
# 2  -7.905447   3.323639       0
# 3   6.411041   5.523013       1
# 4   7.288599   6.171226       1

# %%
# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
#  ### Data Preprocessing
#
#  Use `train_test_split` to create training and testing data.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
#  Scale the data using the `StandarScaler`.

# %%
# Create scaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
#  ### Neural Network Model Creation

# %%
# Create a sequential model
neuron = Sequential()
# Out:
# 2023-02-16 20:08:08.237100: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# The initial step is to add the first layer of our neural network.
#
# ![First Layer](../Images/tensorflow-neuron-layer-1.png)

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 1

neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %% [markdown]
# We finish creating our neural network by adding the output layer.
#
# ![Output layer](../Images/tensorflow-neuron-output-layer.png)

# %%
# Output layer
number_classes = 1

neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  ### Compile the Model

# %%
# Compile model
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
#  ### Fit the Model

# %%
# Fitting the model with linear dummy data
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.9787
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5304 - accuracy: 1.0000
# Epoch 3/100
# 24/24 [==============================] - 0s 972us/step - loss: 0.5170 - accuracy: 1.0000
# Epoch 4/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.5035 - accuracy: 1.0000
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4901 - accuracy: 1.0000
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4767 - accuracy: 1.0000
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4635 - accuracy: 1.0000
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 1.0000
# Epoch 9/100
# 24/24 [==============================] - 0s 966us/step - loss: 0.4376 - accuracy: 1.0000
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4251 - accuracy: 1.0000
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4128 - accuracy: 1.0000
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 1.0000
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3894 - accuracy: 1.0000
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3782 - accuracy: 1.0000
# Epoch 15/100
# 24/24 [==============================] - 0s 926us/step - loss: 0.3674 - accuracy: 1.0000
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 1.0000
# Epoch 17/100
# 24/24 [==============================] - 0s 857us/step - loss: 0.3470 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3373 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3281 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 931us/step - loss: 0.3192 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3106 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3023 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 878us/step - loss: 0.2943 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2867 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 903us/step - loss: 0.2793 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2723 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2655 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 860us/step - loss: 0.2589 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2526 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2465 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2349 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2295 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2242 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2191 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 982us/step - loss: 0.2142 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2094 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2048 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2003 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1838 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1800 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1763 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1727 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1692 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1658 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1625 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1593 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1562 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1474 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 938us/step - loss: 0.1419 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1392 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1367 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1342 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1271 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1248 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1204 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1183 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1123 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1104 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1085 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1014 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0949 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0934 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0762 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0751 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0729 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0707 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0697 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 887us/step - loss: 0.0686 - accuracy: 1.0000

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a DataFrame with the history dictionary
df = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# Plot the loss
df.plot(y="loss")
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
df.plot(y="accuracy")
# Out:
# <AxesSubplot: >

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0700 - accuracy: 1.0000 - 222ms/epoch - 28ms/step
# Loss: 0.06999856978654861, Accuracy: 1.0

# %% [markdown]
#  ### Making Predictions with New Data

# %%
# Create 10 new samples of dummy data
new_X, new_y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)

# %%
# Making predictions
predictions = (neuron.predict(new_X) > 0.5).astype("int32")
results = pd.DataFrame({"predictions": predictions.ravel(), "actual": new_y})
results.head(10)
# Out:
# 1/1 [==============================] - 0s 117ms/step
#    predictions  actual
# 0            0       0
# 1            1       1
# 2            0       0
# 3            1       1
# 4            0       0
# 5            0       0
# 6            1       1
# 7            1       1
# 8            1       1
# 9            0       0

# %% [markdown]
# ---

# %% [markdown]
# # Using a Single Neuron for Non-Linear Data
#
# ### Creating Demo Data:

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data
df_moons.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
# ### Data Preprocessing
#
# Use `train_test_split` to create training and testing data.

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %% [markdown]
#  Scale the data

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
#  ### Fit the Model

# %%
# Training the model with the non-linear data
model_moon = neuron.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1082 - accuracy: 0.4813
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9865 - accuracy: 0.5080
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9075 - accuracy: 0.5200
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8504 - accuracy: 0.5333
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8083 - accuracy: 0.5453
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7732 - accuracy: 0.5600
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7441 - accuracy: 0.5667
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7175 - accuracy: 0.5853
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6946 - accuracy: 0.5893
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6743 - accuracy: 0.6040
# Epoch 11/100
# 24/24 [==============================] - 0s 889us/step - loss: 0.6549 - accuracy: 0.6173
# Epoch 12/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.6376 - accuracy: 0.6253
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6200 - accuracy: 0.6360
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6035 - accuracy: 0.6453
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5867 - accuracy: 0.6520
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5714 - accuracy: 0.6627
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5563 - accuracy: 0.6680
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5424 - accuracy: 0.6720
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5296 - accuracy: 0.6800
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5174 - accuracy: 0.6853
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5061 - accuracy: 0.6947
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4951 - accuracy: 0.7000
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7067
# Epoch 24/100
# 24/24 [==============================] - 0s 982us/step - loss: 0.4754 - accuracy: 0.7160
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4662 - accuracy: 0.7213
# Epoch 26/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4575 - accuracy: 0.7267
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.7320
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4413 - accuracy: 0.7440
# Epoch 29/100
# 24/24 [==============================] - 0s 927us/step - loss: 0.4338 - accuracy: 0.7453
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4263 - accuracy: 0.7560
# Epoch 31/100
# 24/24 [==============================] - 0s 949us/step - loss: 0.4194 - accuracy: 0.7627
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4126 - accuracy: 0.7720
# Epoch 33/100
# 24/24 [==============================] - 0s 973us/step - loss: 0.4060 - accuracy: 0.7773
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3994 - accuracy: 0.7800
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.7827
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.7893
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3817 - accuracy: 0.7907
# Epoch 38/100
# 24/24 [==============================] - 0s 978us/step - loss: 0.3760 - accuracy: 0.7933
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3707 - accuracy: 0.8053
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3656 - accuracy: 0.8107
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8133
# Epoch 42/100
# 24/24 [==============================] - 0s 917us/step - loss: 0.3564 - accuracy: 0.8173
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8187
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8240
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3441 - accuracy: 0.8253
# Epoch 46/100
# 24/24 [==============================] - 0s 969us/step - loss: 0.3405 - accuracy: 0.8267
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3369 - accuracy: 0.8267
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.8267
# Epoch 49/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3305 - accuracy: 0.8307
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3275 - accuracy: 0.8307
# Epoch 51/100
# 24/24 [==============================] - 0s 978us/step - loss: 0.3246 - accuracy: 0.8320
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3220 - accuracy: 0.8333
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3193 - accuracy: 0.8413
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3167 - accuracy: 0.8427
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3143 - accuracy: 0.8453
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3120 - accuracy: 0.8480
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3098 - accuracy: 0.8507
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3077 - accuracy: 0.8507
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3058 - accuracy: 0.8547
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3038 - accuracy: 0.8587
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3020 - accuracy: 0.8627
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3003 - accuracy: 0.8627
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2985 - accuracy: 0.8640
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.8640
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2953 - accuracy: 0.8667
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2938 - accuracy: 0.8680
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2924 - accuracy: 0.8680
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2910 - accuracy: 0.8680
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2896 - accuracy: 0.8680
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2883 - accuracy: 0.8680
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2870 - accuracy: 0.8693
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.8707
# Epoch 73/100
# 24/24 [==============================] - 0s 992us/step - loss: 0.2847 - accuracy: 0.8707
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2835 - accuracy: 0.8747
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2825 - accuracy: 0.8760
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.8773
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2805 - accuracy: 0.8773
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2796 - accuracy: 0.8787
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2786 - accuracy: 0.8787
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2777 - accuracy: 0.8800
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2769 - accuracy: 0.8800
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2761 - accuracy: 0.8813
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.8813
# Epoch 84/100
# 24/24 [==============================] - 0s 947us/step - loss: 0.2745 - accuracy: 0.8827
# Epoch 85/100
# 24/24 [==============================] - 0s 928us/step - loss: 0.2737 - accuracy: 0.8813
# Epoch 86/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.2730 - accuracy: 0.8840
# Epoch 87/100
# 24/24 [==============================] - 0s 907us/step - loss: 0.2724 - accuracy: 0.8867
# Epoch 88/100
# 24/24 [==============================] - 0s 927us/step - loss: 0.2717 - accuracy: 0.8867
# Epoch 89/100
# 24/24 [==============================] - 0s 946us/step - loss: 0.2711 - accuracy: 0.8867
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2704 - accuracy: 0.8867
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.8867
# Epoch 92/100
# 24/24 [==============================] - 0s 917us/step - loss: 0.2692 - accuracy: 0.8867
# Epoch 93/100
# 24/24 [==============================] - 0s 909us/step - loss: 0.2687 - accuracy: 0.8867
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8853
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.8853
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2671 - accuracy: 0.8853
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.8853
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2661 - accuracy: 0.8853
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2657 - accuracy: 0.8853
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2653 - accuracy: 0.8853

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a DataFrame with the history dictionary
df_moon = pd.DataFrame(
    model_moon.history, index=range(1, len(model_moon.history["loss"]) + 1)
)

# Plot the loss
df_moon.plot(y="loss")
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
df_moon.plot(y="accuracy")
# Out:
# <AxesSubplot: >

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model using non-linear data
model_moon_loss, model_moon_accuracy = neuron.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.2837 - accuracy: 0.8520 - 37ms/epoch - 5ms/step
# Loss: 0.2836931347846985, Accuracy: 0.8519999980926514

# %% [markdown]
#  ### Making Predictions

# %%
# Create demo data
X_new_moons, y_new_moons = make_moons(n_samples=10, noise=0.08, random_state=78)

# %%
# Making predictions
predictions_moon = (neuron.predict(X_new_moons) > 0.5).astype("int32")

results = pd.DataFrame({"predictions": predictions_moon.ravel(), "actual": y_new_moons})
results.head(10)
# Out:
# 1/1 [==============================] - 0s 25ms/step
#    predictions  actual
# 0            0       0
# 1            0       0
# 2            0       0
# 3            1       1
# 4            1       1
# 5            0       0
# 6            1       0
# 7            1       1
# 8            1       1
# 9            0       1
